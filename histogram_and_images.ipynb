# %% [markdown]
# <a href="https://colab.research.google.com/github/suhasAB/Numpy-Stack/blob/main/histogram_and_images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X=np.random.randn(1000)

# %%
plt.hist(X);

# %%
plt.hist(X,bins=50);

# %%
X=np.random.random(10000)
plt.hist(X,bins=50);

# %% [markdown]
# # Plotting Images

# %%
# !wget https://www.cricketcountry.com/wp-content/uploads/2017/04/M-Chinnasawamy-.jpg
# Out:
# --2021-05-08 12:50:32--  https://www.cricketcountry.com/wp-content/uploads/2017/04/M-Chinnasawamy-.jpg
# Resolving www.cricketcountry.com (www.cricketcountry.com)... 23.6.151.208, 2600:1407:b800:196::2965, 2600:1407:b800:195::2965
# Connecting to www.cricketcountry.com (www.cricketcountry.com)|23.6.151.208|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 345120 (337K) [image/jpeg]
# Saving to: ‘M-Chinnasawamy-.jpg’
#
# M-Chinnasawamy-.jpg 100%[===================>] 337.03K   651KB/s    in 0.5s
#
# 2021-05-08 12:50:33 (651 KB/s) - ‘M-Chinnasawamy-.jpg’ saved [345120/345120]

# %%
from PIL import Image

# %%
im=Image.open('M-Chinnasawamy-.jpg')

# %%
type(im)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
arr=np.array(im)

# %%
arr
# Out:
# array([[[  2,   2,   0],
#         [  1,   1,   1],
#         [  1,   1,   1],
#         ...,
#         [  8,  13,  17],
#         [  6,  14,  17],
#         [255, 255, 255]],
#
#        [[  1,   1,   0],
#         [  0,   0,   0],
#         [  0,   0,   0],
#         ...,
#         [  6,  14,  17],
#         [  6,  14,  17],
#         [254, 255, 255]],
#
#        [[  2,   2,   0],
#         [  0,   0,   0],
#         [  0,   0,   0],
#         ...,
#         [  7,  15,  18],
#         [  7,  15,  18],
#         [255, 255, 255]],
#
#        ...,
#
#        [[  2,   4,   3],
#         [  0,   0,   0],
#         [  0,   0,   0],
#         ...,
#         [137, 162,  78],
#         [126, 156,  70],
#         [255, 255, 255]],
#
#        [[  2,   2,   2],
#         [  0,   0,   0],
#         [  0,   0,   0],
#         ...,
#         [131, 159,  72],
#         [140, 163,  83],
#         [255, 255, 255]],
#
#        [[  4,   6,   3],
#         [  2,   4,   1],
#         [  5,   5,   3],
# ...

# %%
arr.shape
# Out:
# (355, 628, 3)

# %%
plt.imshow(arr);

# %%
plt.imshow(im);

# %%
gray=arr.mean(axis=2)

# %%
gray.shape
# Out:
# (355, 628)

# %%
plt.imshow(gray);

# %%
plt.imshow(gray,cmap="gray");

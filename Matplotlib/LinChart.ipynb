# %% [markdown]
# <a href="https://colab.research.google.com/github/suhasAB/Numpy-Stack/blob/main/Linechart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.linspace(0,20,1000)

# %%
y=np.sin(x)+ 0.2*x

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.xlabel('input')
plt.ylabel('output')
plt.title("my plot");
